# %%
import os
from flask import Flask, jsonify

app = Flask(__name__)
@app.route('/')
def home():
    return "Hello World from Render Etudiant!"
@app.route('/api/data')
def data():
    return jsonify({"message": "Exemple de JSON via un PaaS"})
if __name__ == "__main__":
    port = int(os.environ.get("PORT", 5000))
    app.run(host="0.0.0.0", port=port)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.43.119:5000/ (Press CTRL+C to quit)
# 192.168.43.119 - - [01/Mar/2026 23:39:12] "GET / HTTP/1.1" 200 -
# 192.168.43.119 - - [01/Mar/2026 23:39:12] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [01/Mar/2026 23:40:42] "GET /api/data HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2026 23:40:42] "GET /favicon.ico HTTP/1.1" 404 -
